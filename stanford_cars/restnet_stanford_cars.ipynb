# %% [markdown]
# # Car Image Classification using ResNet (Residual Network) and Stanford Cars Dataset in PyTorch
#
# ResNet, short for Residual Network is a specific type of neural network that was introduced in 2015 by Kaiming He, Xiangyu Zhang, Shaoqing Ren and Jian Sun in their paper [“Deep Residual Learning for Image Recognition”](https://arxiv.org/pdf/1512.03385.pdf). <br/>
# ResNet was an innovative approach over VGG-like models:
# * Won 1st place in the ILSVRC 2015 classification competition with a top-5 error rate of 3.57% (An ensemble model)
# * Won the 1st place in ILSVRC and COCO 2015 competition in ImageNet Detection, ImageNet localization, Coco detection and Coco segmentation.
# * Replacing VGG-16 layers in Faster R-CNN with ResNet-101. They observed relative improvements of 28%
# * Efficiently trained networks with 100 layers and 1000 layers also.
#
# We get over 70% accuracy without using any pre-trained model in 100 epochs and it proves the power of ResNet.
#
# In this notebook, I will be implementing less complex version of ResNets to be able to get results in reasonable amount of time. Even though the implementation is done through CIFAR-100 dataset, it can be used with any image classification dataset. <br/>Note: Do not forget to change transform values if you use different the dataset. You can find the best parameters from SOTA implementations for well-known datasets.
#
# #### References which I got implementations and explanations.
# - [weiaicunzai/pytorch-cifar100](https://github.com/weiaicunzai/pytorch-cifar100/blob/master/models/resnet.py)
# - [papers-with-code](https://paperswithcode.com/sota/image-classification-on-cifar-100)
# - [pytorch-basic-cifar10](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html)
# - [more-implementation-with-explanations](https://blog.jovian.ai/image-classification-of-cifar100-dataset-using-pytorch-8b7145242df1)
# - [more-reading](https://www.researchgate.net/publication/355698607_MEST_Accurate_and_Fast_Memory-Economic_Sparse_Training_Framework_on_the_Edge)
# - [visualization](https://jovian.ai/damian-c036/cifar100-final-project/v/5?utm_source=embed)
#
#
# So we are good to go.

# %% [markdown]
# # Necessary Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import StanfordCars
from torchvision.utils import make_grid
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split, ConcatDataset
import torchvision.transforms as tt

# %% [markdown]
# ____
# #### Before we load the data, it is required to first prepare the transformations to be applied. It is an important step to prepare the data for training to avoid overfitting problem.
# ____

# %%
# Mean and Standard Deviation Calculation
from tqdm import tqdm

stats_transform = tt.Compose([
    tt.Resize((224, 224)),
    tt.ToTensor()
])

train_data_for_stats = StanfordCars(
    root = "./data",
    split = "train",
    download = False,
    transform = stats_transform
)

train_dl_for_stats = DataLoader(
    train_data_for_stats,
    batch_size = 32,
    shuffle = False,
    num_workers = 2
)

mean = torch.zeros(3)
ex2 = torch.zeros(3)
total_pixels = 0

loop = tqdm(train_dl_for_stats)

for images, _ in loop:
    B, C, H, W = images.shape
    images = images.view(B, C, -1)

    mean += images.sum(dim=(0, 2))
    ex2 += (images ** 2).sum(dim=(0, 2))
    total_pixels += B * H * W

    loop.set_description("Calculating mean/std")

mean /= total_pixels
ex2 /= total_pixels
std = torch.sqrt(ex2 - mean ** 2)

print("Mean:", mean)
print("Std:", std)
# Out:
# Calculating mean/std: 100%|██████████| 255/255 [00:21<00:00, 12.13it/s]
# Mean: tensor([0.4708, 0.4602, 0.4550])
# Std: tensor([0.2891, 0.2882, 0.2967])

# %%
# stats = ((0.5074,0.4867,0.4411),(0.2011,0.1987,0.2025))

# https://explore.albumentations.ai/transform/Normalize/docs
stats = ((0.4708, 0.4602, 0.4550),(0.2891, 0.2882, 0.2967)) # mean for RGB, standard deviation for RGB

train_transform = tt.Compose([
    tt.Resize((224, 224)),
    tt.RandomHorizontalFlip(),
    tt.RandomRotation(15),
    tt.ToTensor(),  
    tt.Normalize(*stats)
])

test_transform = tt.Compose([
    tt.Resize((224, 224)),
    tt.ToTensor(),
    tt.Normalize(*stats)
])

# %% [markdown]
# ___
# RandomHorizontalFlip randomly flips an image with a probability of 50%, and RandomCrop pads an image by 4 pixel on each side then randomly crops 32x32 from the image after padding. We add such transformations to add noise to the data and prevent our model from overfitting. There are also other transformations you can use such as ColorJitter and RandomVerticalFlip etc. but I found these to be sufficient for our purposes. <br />
#
# ToTensor simply converts the image to a Tensor. Since its a coloured image, it would have 3 channels (R,G,B) so the Tensor would be of size 3x32x32. <br/>
#
# Normalize takes the mean and standard deviation for each channel of the entire dataset as input. Normalizing scales our data to a similar range of values to make sure that our gradients don’t go out of control.
# Now we just prepare our train and test dataset and then we can explore the data.
# ___

# %% [markdown]
# # Loading Data

# %%
# train_data = StanfordCars(download = False, root = "./data", transform = train_transform)
# test_data = StanfordCars(root = "./data", transform = test_transform)
train_data = StanfordCars(
    download = False,
    root = "./data",
    split = "train",
    transform = train_transform
)

test_data = StanfordCars(
    download = False,
    root = "./data",
    split = "test",
    transform = test_transform
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 10
#       1 # train_data = StanfordCars(download = False, root = "./data", transform = train_transform)
#       2 # test_data = StanfordCars(root = "./data", transform = test_transform)
#       3 train_data = StanfordCars(
#       4     download = False,
#       5     root = "./data",
#       6     split = "train",
#       7     transform = train_transform
#       8 )
# ---> 10 test_data = StanfordCars(
#      11     download = False,
#      12     root = "./data",
#      13     split = "test",
#      14     transform = test_transform
#      15 )
#
# File ~/machine_learning/ml-env/lib/python3.13/site-packages/torchvision/datasets/stanford_cars.py:75, in StanfordCars.__init__(self, root, split, transform, target_transform, download, loader)
#      69 if not self._check_exists():
#      70     raise RuntimeError("Dataset not found.")
#      72 self._samples = [
#      73     (
#      74         str(self._images_base_path / annotation["fname"]),
# ---> 75         annotation["class"] - 1,  # Original target mapping  starts from 1, hence -1
#      76     )
#      77     for annotation in sio.loadmat(self._annotations_mat_path, squeeze_me=True)["annotations"]
#      78 ]
#      80 self.classes = sio.loadmat(str(devkit / "cars_meta.mat"), squeeze_me=True)["class_names"].tolist()
#      81 self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}
#
# ValueError: no field of name class

# %% [markdown]
# _____

# %%
for image, label in train_data:
    print("Image shape: ",image.shape)
    print("Image tensor: ", image)
    print("Label: ", label)
    break
# Out:
# Image shape:  torch.Size([3, 224, 224])
# Image tensor:  tensor([[[-1.6285, -1.6285, -1.6285,  ..., -0.4348, -0.4484, -1.6285],
#          [ 1.7491,  1.7627,  1.7762,  ..., -0.5569, -0.5026, -1.6285],
#          [ 1.7356,  1.7356,  1.7762,  ..., -0.5026, -0.5298, -1.6285],
#          ...,
#          [-1.6285, -0.3941, -0.3805,  ...,  0.5961,  0.6097,  0.6504],
#          [-1.6285, -0.4348, -0.4619,  ...,  0.7318,  0.6911,  0.6368],
#          [-1.6285, -0.7332, -0.7197,  ..., -1.6285, -1.6285, -1.6285]],
#
#         [[-1.5968, -1.5968, -1.5968,  ..., -0.1545, -0.1681, -1.5968],
#          [ 1.8730,  1.8730,  1.8730,  ..., -0.2769, -0.2225, -1.5968],
#          [ 1.8594,  1.8594,  1.8730,  ..., -0.2225, -0.2497, -1.5968],
#          ...,
#          [-1.5968, -0.2769, -0.2497,  ...,  0.6348,  0.6484,  0.7164],
#          [-1.5968, -0.2633, -0.2905,  ...,  0.7572,  0.7436,  0.7028],
#          [-1.5968, -0.5218, -0.5218,  ..., -1.5968, -1.5968, -1.5968]],
#
#         [[-1.5335, -1.5335, -1.5335,  ..., -0.0796, -0.0929, -1.5335],
#          [ 1.8369,  1.8369,  1.8369,  ..., -0.1986, -0.1457, -1.5335],
#          [ 1.8237,  1.8237,  1.8369,  ..., -0.1457, -0.1722, -1.5335],
#          ...,
#          [-1.5335, -0.1986, -0.1854,  ...,  0.5151,  0.5284,  0.5548],
#          [-1.5335, -0.2118, -0.2382,  ...,  0.6473,  0.6209,  0.5416],
#          [-1.5335, -0.5026, -0.4894,  ..., -1.5335, -1.5335, -1.5335]]])
# Label:  13

# %%
train_classes_items = dict()

for train_item in train_data:
    label = train_data.classes[train_item[1]]
    if label not in train_classes_items:
        train_classes_items[label] = 1
    else:
        train_classes_items[label] += 1

train_classes_items
# Out:
# {'Audi TTS Coupe 2012': 43,
#  'Acura TL Sedan 2012': 43,
#  'Dodge Dakota Club Cab 2007': 39,
#  'Hyundai Sonata Hybrid Sedan 2012': 34,
#  'Ford F-450 Super Duty Crew Cab 2012': 42,
#  'Geo Metro Convertible 1993': 45,
#  'Dodge Journey SUV 2012': 44,
#  'Dodge Charger Sedan 2012': 41,
#  'Mitsubishi Lancer Sedan 2012': 48,
#  'Chevrolet Traverse SUV 2012': 44,
#  'Buick Verano Sedan 2012': 38,
#  'Toyota Sequoia SUV 2012': 39,
#  'Hyundai Elantra Sedan 2007': 42,
#  'Dodge Caravan Minivan 1997': 44,
#  'Volvo C30 Hatchback 2012': 42,
#  'Plymouth Neon Coupe 1999': 44,
#  'Chevrolet Malibu Sedan 2007': 45,
#  'Volkswagen Beetle Hatchback 2012': 43,
#  'Chevrolet Corvette Ron Fellows Edition Z06 2007': 38,
#  'Chrysler 300 SRT-8 2010': 49,
#  'BMW M6 Convertible 2010': 41,
#  'GMC Yukon Hybrid SUV 2012': 43,
#  'Nissan Juke Hatchback 2012': 44,
#  'Volvo 240 Sedan 1993': 46,
#  'Suzuki SX4 Sedan 2012': 41,
#  'Dodge Ram Pickup 3500 Crew Cab 2010': 43,
#  'Spyker C8 Coupe 2009': 43,
#  'Land Rover Range Rover SUV 2012': 43,
#  'Hyundai Elantra Touring Hatchback 2012': 43,
#  'Chevrolet Cobalt SS 2010': 42,
#  'Hyundai Veracruz SUV 2012': 42,
#  'Ferrari 458 Italia Coupe 2012': 43,
#  'BMW Z4 Convertible 2012': 41,
#  'Dodge Charger SRT-8 2009': 42,
#  'Fisker Karma Sedan 2012': 44,
#  'Infiniti QX56 SUV 2011': 33,
#  'Audi A5 Coupe 2012': 41,
#  'Volkswagen Golf Hatchback 1991': 46,
#  'GMC Savana Van 2012': 68,
#  'Audi TT RS Coupe 2012': 40,
#  'Rolls-Royce Phantom Sedan 2012': 44,
#  'Porsche Panamera Sedan 2012': 44,
#  'Bentley Continental GT Coupe 2012': 35,
#  'Jeep Grand Cherokee SUV 2012': 45,
#  'Audi R8 Coupe 2012': 43,
#  'Cadillac Escalade EXT Crew Cab 2007': 45,
#  'Bentley Continental Flying Spur Sedan 2007': 45,
#  'Chevrolet Avalanche Crew Cab 2012': 45,
#  'Dodge Dakota Crew Cab 2010': 41,
#  'HUMMER H3T Crew Cab 2010': 39,
#  'Ford F-150 Regular Cab 2007': 45,
#  'Volkswagen Golf Hatchback 2012': 43,
#  'Ferrari FF Coupe 2012': 42,
#  'Toyota Camry Sedan 2012': 44,
#  'Aston Martin V8 Vantage Convertible 2012': 45,
#  'Audi 100 Sedan 1994': 41,
#  'Ford Ranger SuperCab 2011': 42,
#  'GMC Canyon Extended Cab 2012': 40,
#  'Acura TSX Sedan 2012': 41,
#  'BMW 3 Series Sedan 2012': 43,
#  'Honda Odyssey Minivan 2012': 42,
#  'Dodge Durango SUV 2012': 44,
#  'Toyota Corolla Sedan 2012': 44,
#  'Chevrolet Camaro Convertible 2012': 45,
#  'Ford Edge SUV 2012': 43,
#  'Bentley Continental GT Coupe 2007': 46,
#  'Audi 100 Wagon 1994': 43,
#  'Ford E-Series Wagon Van 2012': 38,
#  'Jeep Patriot SUV 2012': 44,
#  'Audi S6 Sedan 2011': 46,
#  'Mercedes-Benz S-Class Sedan 2012': 45,
#  'Hyundai Sonata Sedan 2012': 40,
#  'Rolls-Royce Phantom Drophead Coupe Convertible 2012': 31,
#  'Ford GT Coupe 2006': 46,
#  'Cadillac CTS-V Sedan 2012': 43,
#  'BMW X3 SUV 2012': 39,
#  'Chevrolet Express Van 2007': 35,
#  'Chevrolet Impala Sedan 2007': 43,
#  'Chevrolet Silverado 1500 Extended Cab 2012': 44,
#  'Mercedes-Benz C-Class Sedan 2012': 46,
#  'Hyundai Santa Fe SUV 2012': 42,
#  'Dodge Sprinter Cargo Van 2009': 40,
#  'GMC Acadia SUV 2012': 45,
#  'Hyundai Genesis Sedan 2012': 44,
#  'Dodge Caliber Wagon 2012': 41,
#  'Jeep Liberty SUV 2012': 45,
#  'Mercedes-Benz 300-Class Convertible 1993': 48,
#  'Ford Expedition EL SUV 2009': 45,
#  'BMW 1 Series Coupe 2012': 41,
#  'Jaguar XK XKR 2012': 47,
#  'Hyundai Accent Sedan 2012': 24,
#  'Isuzu Ascender SUV 2008': 40,
#  'Nissan 240SX Coupe 1998': 46,
#  'Scion xD Hatchback 2012': 42,
#  'Chevrolet Corvette ZR1 2012': 47,
#  'Bentley Arnage Sedan 2009': 39,
#  'Chevrolet HHR SS 2010': 37,
#  'Land Rover LR2 SUV 2012': 43,
#  'Hyundai Azera Sedan 2012': 42,
#  'Chrysler Aspen SUV 2009': 44,
#  'Buick Regal GS 2012': 35,
#  'BMW 3 Series Wagon 2012': 42,
#  'Jeep Compass SUV 2012': 43,
#  'Ram C/V Cargo Van Minivan 2012': 41,
#  'Spyker C8 Convertible 2009': 45,
#  'Audi S4 Sedan 2007': 45,
#  'Rolls-Royce Ghost Sedan 2012': 39,
#  'AM General Hummer SUV 2000': 45,
#  'Ford Freestar Minivan 2007': 44,
#  'Bentley Mulsanne Sedan 2011': 36,
#  'Audi TT Hatchback 2011': 41,
#  'Mercedes-Benz SL-Class Coupe 2009': 37,
#  'Chevrolet Silverado 1500 Hybrid Crew Cab 2012': 40,
#  'Buick Enclave SUV 2012': 42,
#  'Chevrolet TrailBlazer SS 2009': 40,
#  'HUMMER H2 SUT Crew Cab 2009': 44,
#  'McLaren MP4-12C Coupe 2012': 44,
#  'Dodge Challenger SRT8 2011': 39,
#  'Suzuki SX4 Hatchback 2012': 42,
#  'Bugatti Veyron 16.4 Convertible 2009': 33,
#  'Toyota 4Runner SUV 2012': 41,
#  'Buick Rainier SUV 2007': 43,
#  'Chrysler Sebring Convertible 2010': 41,
#  'Acura Integra Type R 2001': 45,
#  'Audi V8 Sedan 1994': 44,
#  'Audi RS 4 Convertible 2008': 37,
#  'Honda Accord Coupe 2012': 39,
#  'Audi S4 Sedan 2012': 40,
#  'Aston Martin Virage Coupe 2012': 38,
#  'Chevrolet Sonic Sedan 2012': 44,
#  'Chevrolet Monte Carlo Coupe 2007': 45,
#  'Volvo XC90 SUV 2007': 43,
#  'Ford Mustang Convertible 2007': 45,
#  'Aston Martin Virage Convertible 2012': 33,
#  'smart fortwo Convertible 2012': 40,
#  'FIAT 500 Abarth 2012': 28,
#  'Infiniti G Coupe IPL 2012': 34,
#  'Dodge Caliber Wagon 2007': 42,
#  'Hyundai Tucson SUV 2012': 44,
#  'Acura ZDX Hatchback 2012': 39,
#  'BMW ActiveHybrid 5 Sedan 2012': 34,
#  'Ferrari California Convertible 2012': 39,
#  'Nissan Leaf Hatchback 2012': 42,
#  'Lamborghini Diablo Coupe 2001': 45,
#  'Audi S5 Convertible 2012': 42,
#  'BMW 6 Series Convertible 2007': 44,
#  'Ferrari 458 Italia Convertible 2012': 40,
#  'Chevrolet Silverado 2500HD Regular Cab 2012': 38,
#  'Chevrolet Corvette Convertible 2012': 40,
#  'Bugatti Veyron 16.4 Coupe 2009': 44,
#  'Tesla Model S Sedan 2012': 39,
#  'FIAT 500 Convertible 2012': 34,
#  'Hyundai Veloster Hatchback 2012': 41,
#  'Lincoln Town Car Sedan 2011': 39,
#  'Lamborghini Aventador Coupe 2012': 44,
#  'Dodge Ram Pickup 3500 Quad Cab 2009': 44,
#  'Nissan NV Passenger Van 2012': 39,
#  'Honda Odyssey Minivan 2007': 41,
#  'Maybach Landaulet Convertible 2012': 29,
#  'Chevrolet Silverado 1500 Regular Cab 2012': 44,
#  'Suzuki Kizashi Sedan 2012': 46,
#  'Chevrolet Tahoe Hybrid SUV 2012': 37,
#  'Mercedes-Benz Sprinter Van 2012': 41,
#  'Suzuki Aerio Sedan 2007': 38,
#  'Audi S5 Coupe 2012': 43,
#  'Aston Martin V8 Vantage Coupe 2012': 41,
#  'Chevrolet Malibu Hybrid Sedan 2010': 39,
#  'Ford F-150 Regular Cab 2012': 43,
#  'Ford Fiesta Sedan 2012': 43,
#  'Ford Focus Sedan 2007': 45,
#  'Bentley Continental Supersports Conv. Convertible 2012': 37,
#  'Chevrolet Silverado 1500 Classic Extended Cab 2007': 43,
#  'BMW X5 SUV 2007': 42,
#  'Jeep Wrangler SUV 2012': 43,
#  'Acura TL Type-S 2008': 42,
#  'Chrysler Crossfire Convertible 2008': 43,
#  'Lamborghini Gallardo LP 570-4 Superleggera 2012': 36,
#  'Mercedes-Benz E-Class Sedan 2012': 44,
#  'Chevrolet Express Cargo Van 2007': 30,
#  'GMC Terrain SUV 2012': 42,
#  'Dodge Magnum Wagon 2008': 40,
#  'Honda Accord Sedan 2012': 39,
#  'Chrysler PT Cruiser Convertible 2008': 45,
#  'Mazda Tribute SUV 2011': 36,
#  'BMW M3 Coupe 2012': 45,
#  'Eagle Talon Hatchback 1998': 46,
#  'Daewoo Nubira Wagon 2002': 45,
#  'BMW X6 SUV 2012': 42,
#  'Lamborghini Reventon Coupe 2008': 36,
#  'Cadillac SRX SUV 2012': 41,
#  'MINI Cooper Roadster Convertible 2012': 37,
#  'Acura RL Sedan 2012': 32,
#  'BMW 1 Series Convertible 2012': 36,
#  'Dodge Durango SUV 2007': 46,
#  'BMW M5 Sedan 2010': 41,
#  'Chrysler Town and Country Minivan 2012': 38}

# %%
test_classes_items = dict()
for test_item in test_data:
    label = test_data.classes[test_item[1]]
    if label not in test_classes_items:
        test_classes_items[label] = 1
    else:
        test_classes_items[label] += 1

test_classes_items
# Out:
# {'Audi TTS Coupe 2012': 43,
#  'Acura TL Sedan 2012': 43,
#  'Dodge Dakota Club Cab 2007': 39,
#  'Hyundai Sonata Hybrid Sedan 2012': 34,
#  'Ford F-450 Super Duty Crew Cab 2012': 42,
#  'Geo Metro Convertible 1993': 45,
#  'Dodge Journey SUV 2012': 44,
#  'Dodge Charger Sedan 2012': 41,
#  'Mitsubishi Lancer Sedan 2012': 48,
#  'Chevrolet Traverse SUV 2012': 44,
#  'Buick Verano Sedan 2012': 38,
#  'Toyota Sequoia SUV 2012': 39,
#  'Hyundai Elantra Sedan 2007': 42,
#  'Dodge Caravan Minivan 1997': 44,
#  'Volvo C30 Hatchback 2012': 42,
#  'Plymouth Neon Coupe 1999': 44,
#  'Chevrolet Malibu Sedan 2007': 45,
#  'Volkswagen Beetle Hatchback 2012': 43,
#  'Chevrolet Corvette Ron Fellows Edition Z06 2007': 38,
#  'Chrysler 300 SRT-8 2010': 49,
#  'BMW M6 Convertible 2010': 41,
#  'GMC Yukon Hybrid SUV 2012': 43,
#  'Nissan Juke Hatchback 2012': 44,
#  'Volvo 240 Sedan 1993': 46,
#  'Suzuki SX4 Sedan 2012': 41,
#  'Dodge Ram Pickup 3500 Crew Cab 2010': 43,
#  'Spyker C8 Coupe 2009': 43,
#  'Land Rover Range Rover SUV 2012': 43,
#  'Hyundai Elantra Touring Hatchback 2012': 43,
#  'Chevrolet Cobalt SS 2010': 42,
#  'Hyundai Veracruz SUV 2012': 42,
#  'Ferrari 458 Italia Coupe 2012': 43,
#  'BMW Z4 Convertible 2012': 41,
#  'Dodge Charger SRT-8 2009': 42,
#  'Fisker Karma Sedan 2012': 44,
#  'Infiniti QX56 SUV 2011': 33,
#  'Audi A5 Coupe 2012': 41,
#  'Volkswagen Golf Hatchback 1991': 46,
#  'GMC Savana Van 2012': 68,
#  'Audi TT RS Coupe 2012': 40,
#  'Rolls-Royce Phantom Sedan 2012': 44,
#  'Porsche Panamera Sedan 2012': 44,
#  'Bentley Continental GT Coupe 2012': 35,
#  'Jeep Grand Cherokee SUV 2012': 45,
#  'Audi R8 Coupe 2012': 43,
#  'Cadillac Escalade EXT Crew Cab 2007': 45,
#  'Bentley Continental Flying Spur Sedan 2007': 45,
#  'Chevrolet Avalanche Crew Cab 2012': 45,
#  'Dodge Dakota Crew Cab 2010': 41,
#  'HUMMER H3T Crew Cab 2010': 39,
#  'Ford F-150 Regular Cab 2007': 45,
#  'Volkswagen Golf Hatchback 2012': 43,
#  'Ferrari FF Coupe 2012': 42,
#  'Toyota Camry Sedan 2012': 44,
#  'Aston Martin V8 Vantage Convertible 2012': 45,
#  'Audi 100 Sedan 1994': 41,
#  'Ford Ranger SuperCab 2011': 42,
#  'GMC Canyon Extended Cab 2012': 40,
#  'Acura TSX Sedan 2012': 41,
#  'BMW 3 Series Sedan 2012': 43,
#  'Honda Odyssey Minivan 2012': 42,
#  'Dodge Durango SUV 2012': 44,
#  'Toyota Corolla Sedan 2012': 44,
#  'Chevrolet Camaro Convertible 2012': 45,
#  'Ford Edge SUV 2012': 43,
#  'Bentley Continental GT Coupe 2007': 46,
#  'Audi 100 Wagon 1994': 43,
#  'Ford E-Series Wagon Van 2012': 38,
#  'Jeep Patriot SUV 2012': 44,
#  'Audi S6 Sedan 2011': 46,
#  'Mercedes-Benz S-Class Sedan 2012': 45,
#  'Hyundai Sonata Sedan 2012': 40,
#  'Rolls-Royce Phantom Drophead Coupe Convertible 2012': 31,
#  'Ford GT Coupe 2006': 46,
#  'Cadillac CTS-V Sedan 2012': 43,
#  'BMW X3 SUV 2012': 39,
#  'Chevrolet Express Van 2007': 35,
#  'Chevrolet Impala Sedan 2007': 43,
#  'Chevrolet Silverado 1500 Extended Cab 2012': 44,
#  'Mercedes-Benz C-Class Sedan 2012': 46,
#  'Hyundai Santa Fe SUV 2012': 42,
#  'Dodge Sprinter Cargo Van 2009': 40,
#  'GMC Acadia SUV 2012': 45,
#  'Hyundai Genesis Sedan 2012': 44,
#  'Dodge Caliber Wagon 2012': 41,
#  'Jeep Liberty SUV 2012': 45,
#  'Mercedes-Benz 300-Class Convertible 1993': 48,
#  'Ford Expedition EL SUV 2009': 45,
#  'BMW 1 Series Coupe 2012': 41,
#  'Jaguar XK XKR 2012': 47,
#  'Hyundai Accent Sedan 2012': 24,
#  'Isuzu Ascender SUV 2008': 40,
#  'Nissan 240SX Coupe 1998': 46,
#  'Scion xD Hatchback 2012': 42,
#  'Chevrolet Corvette ZR1 2012': 47,
#  'Bentley Arnage Sedan 2009': 39,
#  'Chevrolet HHR SS 2010': 37,
#  'Land Rover LR2 SUV 2012': 43,
#  'Hyundai Azera Sedan 2012': 42,
#  'Chrysler Aspen SUV 2009': 44,
#  'Buick Regal GS 2012': 35,
#  'BMW 3 Series Wagon 2012': 42,
#  'Jeep Compass SUV 2012': 43,
#  'Ram C/V Cargo Van Minivan 2012': 41,
#  'Spyker C8 Convertible 2009': 45,
#  'Audi S4 Sedan 2007': 45,
#  'Rolls-Royce Ghost Sedan 2012': 39,
#  'AM General Hummer SUV 2000': 45,
#  'Ford Freestar Minivan 2007': 44,
#  'Bentley Mulsanne Sedan 2011': 36,
#  'Audi TT Hatchback 2011': 41,
#  'Mercedes-Benz SL-Class Coupe 2009': 37,
#  'Chevrolet Silverado 1500 Hybrid Crew Cab 2012': 40,
#  'Buick Enclave SUV 2012': 42,
#  'Chevrolet TrailBlazer SS 2009': 40,
#  'HUMMER H2 SUT Crew Cab 2009': 44,
#  'McLaren MP4-12C Coupe 2012': 44,
#  'Dodge Challenger SRT8 2011': 39,
#  'Suzuki SX4 Hatchback 2012': 42,
#  'Bugatti Veyron 16.4 Convertible 2009': 33,
#  'Toyota 4Runner SUV 2012': 41,
#  'Buick Rainier SUV 2007': 43,
#  'Chrysler Sebring Convertible 2010': 41,
#  'Acura Integra Type R 2001': 45,
#  'Audi V8 Sedan 1994': 44,
#  'Audi RS 4 Convertible 2008': 37,
#  'Honda Accord Coupe 2012': 39,
#  'Audi S4 Sedan 2012': 40,
#  'Aston Martin Virage Coupe 2012': 38,
#  'Chevrolet Sonic Sedan 2012': 44,
#  'Chevrolet Monte Carlo Coupe 2007': 45,
#  'Volvo XC90 SUV 2007': 43,
#  'Ford Mustang Convertible 2007': 45,
#  'Aston Martin Virage Convertible 2012': 33,
#  'smart fortwo Convertible 2012': 40,
#  'FIAT 500 Abarth 2012': 28,
#  'Infiniti G Coupe IPL 2012': 34,
#  'Dodge Caliber Wagon 2007': 42,
#  'Hyundai Tucson SUV 2012': 44,
#  'Acura ZDX Hatchback 2012': 39,
#  'BMW ActiveHybrid 5 Sedan 2012': 34,
#  'Ferrari California Convertible 2012': 39,
#  'Nissan Leaf Hatchback 2012': 42,
#  'Lamborghini Diablo Coupe 2001': 45,
#  'Audi S5 Convertible 2012': 42,
#  'BMW 6 Series Convertible 2007': 44,
#  'Ferrari 458 Italia Convertible 2012': 40,
#  'Chevrolet Silverado 2500HD Regular Cab 2012': 38,
#  'Chevrolet Corvette Convertible 2012': 40,
#  'Bugatti Veyron 16.4 Coupe 2009': 44,
#  'Tesla Model S Sedan 2012': 39,
#  'FIAT 500 Convertible 2012': 34,
#  'Hyundai Veloster Hatchback 2012': 41,
#  'Lincoln Town Car Sedan 2011': 39,
#  'Lamborghini Aventador Coupe 2012': 44,
#  'Dodge Ram Pickup 3500 Quad Cab 2009': 44,
#  'Nissan NV Passenger Van 2012': 39,
#  'Honda Odyssey Minivan 2007': 41,
#  'Maybach Landaulet Convertible 2012': 29,
#  'Chevrolet Silverado 1500 Regular Cab 2012': 44,
#  'Suzuki Kizashi Sedan 2012': 46,
#  'Chevrolet Tahoe Hybrid SUV 2012': 37,
#  'Mercedes-Benz Sprinter Van 2012': 41,
#  'Suzuki Aerio Sedan 2007': 38,
#  'Audi S5 Coupe 2012': 43,
#  'Aston Martin V8 Vantage Coupe 2012': 41,
#  'Chevrolet Malibu Hybrid Sedan 2010': 39,
#  'Ford F-150 Regular Cab 2012': 43,
#  'Ford Fiesta Sedan 2012': 43,
#  'Ford Focus Sedan 2007': 45,
#  'Bentley Continental Supersports Conv. Convertible 2012': 37,
#  'Chevrolet Silverado 1500 Classic Extended Cab 2007': 43,
#  'BMW X5 SUV 2007': 42,
#  'Jeep Wrangler SUV 2012': 43,
#  'Acura TL Type-S 2008': 42,
#  'Chrysler Crossfire Convertible 2008': 43,
#  'Lamborghini Gallardo LP 570-4 Superleggera 2012': 36,
#  'Mercedes-Benz E-Class Sedan 2012': 44,
#  'Chevrolet Express Cargo Van 2007': 30,
#  'GMC Terrain SUV 2012': 42,
#  'Dodge Magnum Wagon 2008': 40,
#  'Honda Accord Sedan 2012': 39,
#  'Chrysler PT Cruiser Convertible 2008': 45,
#  'Mazda Tribute SUV 2011': 36,
#  'BMW M3 Coupe 2012': 45,
#  'Eagle Talon Hatchback 1998': 46,
#  'Daewoo Nubira Wagon 2002': 45,
#  'BMW X6 SUV 2012': 42,
#  'Lamborghini Reventon Coupe 2008': 36,
#  'Cadillac SRX SUV 2012': 41,
#  'MINI Cooper Roadster Convertible 2012': 37,
#  'Acura RL Sedan 2012': 32,
#  'BMW 1 Series Convertible 2012': 36,
#  'Dodge Durango SUV 2007': 46,
#  'BMW M5 Sedan 2010': 41,
#  'Chrysler Town and Country Minivan 2012': 38}

# %% [markdown]
# # BATCHSIZE & DataLoader

# %%
# BATCH_SIZE = 128
BATCH_SIZE = 8 # lower if you don't have a very strong GPU
train_dl = DataLoader(train_data, BATCH_SIZE, num_workers = 4, pin_memory = True, shuffle = True)
test_dl = DataLoader(test_data, BATCH_SIZE, num_workers = 4, pin_memory = True)

# %% [markdown]
# # Visualization

# %%
# for 8 images
train_8_samples = DataLoader(train_data, 8, num_workers = 4, pin_memory = True, shuffle = True)

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize = (20,20))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(train_8_samples)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print(''.join(f'{train_data.classes[labels[j]]:20s}' for j in range(8)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.31425118..1.4365025].
# Acura TSX Sedan 2012Chevrolet Cobalt SS 2010BMW X6 SUV 2012     Audi TT Hatchback 2011BMW Z4 Convertible 2012Dodge Charger SRT-8 2009Ford E-Series Wagon Van 2012Aston Martin Virage Convertible 2012

# %% [markdown]
# # Get CUDA ready

# %%
def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    return torch.device("cpu")

def to_device(data,device):
    if isinstance(data,(list,tuple)):
        return [to_device(x,device) for x in data]
    return data.to(device,non_blocking=True)


class ToDeviceLoader:
    def __init__(self,data,device):
        self.data = data
        self.device = device
        
    def __iter__(self):
        for batch in self.data:
            yield to_device(batch,self.device)
            
    def __len__(self):
        return len(self.data)

# %%
device = get_device()
print(device)

train_dl = ToDeviceLoader(train_dl, device)
test_dl = ToDeviceLoader(test_dl, device)
# Out:
# cuda

# %%
def accuracy(predicted, actual):
    _, predictions = torch.max(predicted, dim=1)
    return torch.tensor(torch.sum(predictions==actual).item()/len(predictions))

# %% [markdown]
# # BaseModel

# %%
class BaseModel(nn.Module):
    def training_step(self,batch):
        images, labels = batch
        out = self(images)
        # loss = F.cross_entropy(out,labels)
        loss = F.cross_entropy(out, labels, label_smoothing = 0.1)
        return loss
    
    def validation_step(self,batch):
        images, labels = batch
        out = self(images)
        # loss = F.cross_entropy(out,labels)
        loss = F.cross_entropy(out, labels, label_smoothing = 0.1)
        acc = accuracy(out,labels)
        return {"val_loss":loss.detach(),"val_acc":acc}
    
    def validation_epoch_end(self,outputs):
        batch_losses = [loss["val_loss"] for loss in outputs]
        loss = torch.stack(batch_losses).mean()
        batch_accuracy = [accuracy["val_acc"] for accuracy in outputs]
        acc = torch.stack(batch_accuracy).mean()
        return {"val_loss":loss.item(),"val_acc":acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %% [markdown]
# # ResNet Implementation
#
# BaseModel allows us to check and record the results of our model every time we train and pretty much just helps us keep track of our progress. This is what our actual model will inherit. <br />
#
# I implemented ResNet with changing a little bit that worked better than the one I got and used as base.<br />
#
# #### An example figure of ResNet approach to understand easily what we will see below as code:
#
# ![image.png](attachment:5e638e86-7b48-499f-847d-741d69568111.png)
# <br/><br/><br/><br/>
# ____

# %%
def conv_shortcut(in_channel, out_channel, stride):
    layers = [nn.Conv2d(in_channel, out_channel, kernel_size=(1,1), stride=(stride, stride)),
             nn.BatchNorm2d(out_channel)]
    return nn.Sequential(*layers)

def block(in_channel, out_channel, k_size,stride, conv=False):
    layers = None
    
    first_layers = [nn.Conv2d(in_channel,out_channel[0], kernel_size=(1,1),stride=(1,1)),
                    nn.BatchNorm2d(out_channel[0]),
                    nn.ReLU(inplace=True)]
    if conv:
        first_layers[0].stride=(stride,stride)
    
    second_layers = [nn.Conv2d(out_channel[0], out_channel[1], kernel_size=(k_size, k_size), stride=(1,1), padding=1),
                    nn.BatchNorm2d(out_channel[1])]

    layers = first_layers + second_layers
    
    return nn.Sequential(*layers)
    

class ResNet(BaseModel):
    
    def __init__(self, in_channels, num_classes):
        super().__init__()
        
        self.stg1 = nn.Sequential(
                                   nn.Conv2d(in_channels=in_channels, out_channels=64, kernel_size=(3),
                                             stride=(1), padding=1),
                                   nn.BatchNorm2d(64),
                                   nn.ReLU(inplace=True),
                                   nn.MaxPool2d(kernel_size=3, stride=2))
        
        ##stage 2
        self.convShortcut2 = conv_shortcut(64,256,1)
        
        self.conv2 = block(64,[64,256],3,1,conv=True)
        self.ident2 = block(256,[64,256],3,1)

        
        ##stage 3
        self.convShortcut3 = conv_shortcut(256,512,2)
        
        self.conv3 = block(256,[128,512],3,2,conv=True)
        self.ident3 = block(512,[128,512],3,2)

        
        ##stage 4
        self.convShortcut4 = conv_shortcut(512,1024,2)
        
        self.conv4 = block(512,[256,1024],3,2,conv=True)
        self.ident4 = block(1024,[256,1024],3,2)
        

        ##Classify
        # self.classifier = nn.Sequential(
        #                                nn.AvgPool2d(kernel_size=(4)),
        #                                nn.Flatten(),
        #                                nn.Linear(1024, num_classes))
        self.pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(1024, num_classes)
        
    def forward(self,inputs):
        out = self.stg1(inputs)
        
        #stage 2
        out = F.relu(self.conv2(out) + self.convShortcut2(out))
        out = F.relu(self.ident2(out) + out)
        out = F.relu(self.ident2(out) + out)
        out = F.relu(self.ident2(out) + out)
        
        #stage3
        out = F.relu(self.conv3(out) + (self.convShortcut3(out)))
        out = F.relu(self.ident3(out) + out)
        out = F.relu(self.ident3(out) + out)
        out = F.relu(self.ident3(out) + out)
        out = F.relu(self.ident3(out) + out)
        
        #stage4             
        out = F.relu(self.conv4(out) + (self.convShortcut4(out)))
        out = F.relu(self.ident4(out) + out)
        out = F.relu(self.ident4(out) + out)
        out = F.relu(self.ident4(out) + out)
        out = F.relu(self.ident4(out) + out)
        out = F.relu(self.ident4(out) + out)
        out = F.relu(self.ident4(out) + out)


        
        #Classify
        # out = self.classifier(out)#100x1024
        out = self.pool(out)                 # shape: [B, 1024, 1, 1]
        out = torch.flatten(out, 1)          # shape: [B, 1024]
        out = self.fc(out)                   # shape: [B, 196]
        
        return out

# %%
# model = ResNet(3,100)
model = ResNet(3, 196) # stanford cars has 196 classes

# %%
model = to_device(model, device)

# %% [markdown]
# # Evaluation & Fit Function for Training

# %%
@torch.no_grad()
def evaluate(model,test_dl):
    model.eval()
    outputs = [model.validation_step(batch) for batch in test_dl]
    return model.validation_epoch_end(outputs)

# %%
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit (epochs, train_dl, test_dl, model, optimizer, max_lr, weight_decay, scheduler, grad_clip=None):
    torch.cuda.empty_cache()
    
    history = []

    best_validation_accuracy = 0.0
    
    optimizer = optimizer(model.parameters(), max_lr, weight_decay = weight_decay)
    
    scheduler = scheduler(optimizer, max_lr, epochs=epochs, steps_per_epoch=len(train_dl))
    
    for epoch in range(epochs):
        model.train()
        
        train_loss = []
        
        lrs = []
        
        for batch in train_dl:
            loss = model.training_step(batch)
            
            # train_loss.append(loss)
            train_loss.append(loss.detach())
            
            loss.backward()
            
            if grad_clip:
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            scheduler.step()
            lrs.append(get_lr(optimizer))

        result = evaluate(model, test_dl)
        result["train_loss"] = torch.stack(train_loss).mean().item()
        result["lrs"] = lrs
        
        validation_accuracy = result['val_acc']

        if validation_accuracy > best_validation_accuracy:
            best_validation_accuracy = validation_accuracy
            torch.save(model.state_dict(), 'stanford_cars_resnet.pth')
            print(f"Updated saved stanford cars model with validation accuracy = {best_validation_accuracy:.4f}")
        
        model.epoch_end(epoch, result)
        history.append(result)
        
    return history

# %% [markdown]
# # Hyperparameters
#
# - **max_lr**: is the maximum learning rate that we set for learning rate scheduler. For the learning rate scheduler we used OneCycleLR, which sets the learning rate to a low learning rate, gradually increases it to the max learning rate then goes back to a low learning rate. <br/>
# - **grad_clip**: prevents the gradients to become too large. <br/>
# - **weight_decay**: essentially tries to make the model simple and helps the model generalise better.

# %%
epochs = 100
# epochs = 79
optimizer = torch.optim.Adam
max_lr = 1e-3
grad_clip = 0.1
weight_decay = 1e-5
scheduler = torch.optim.lr_scheduler.OneCycleLR

# %% [markdown]
# # Training

# %%
# %%time
history = fit(epochs = epochs, train_dl = train_dl, test_dl = test_dl, model = model, 
              optimizer = optimizer, max_lr = max_lr, grad_clip = grad_clip,
              weight_decay = weight_decay, scheduler = torch.optim.lr_scheduler.OneCycleLR)
# Out:
# Updated saved stanford cars model with validation accuracy = 0.0120
# Epoch [0], last_lr: 0.00004, train_loss: 5.3125, val_loss: 5.2252, val_acc: 0.0120
# Updated saved stanford cars model with validation accuracy = 0.0199
# Epoch [1], last_lr: 0.00005, train_loss: 5.1985, val_loss: 5.1743, val_acc: 0.0199
# Updated saved stanford cars model with validation accuracy = 0.0223
# Epoch [2], last_lr: 0.00006, train_loss: 5.1531, val_loss: 5.1747, val_acc: 0.0223
# Epoch [3], last_lr: 0.00008, train_loss: 5.1265, val_loss: 5.1724, val_acc: 0.0216
# Updated saved stanford cars model with validation accuracy = 0.0244
# Epoch [4], last_lr: 0.00010, train_loss: 5.1250, val_loss: 5.1704, val_acc: 0.0244
# Epoch [5], last_lr: 0.00013, train_loss: 5.1325, val_loss: 5.1701, val_acc: 0.0233
# Epoch [6], last_lr: 0.00016, train_loss: 5.1136, val_loss: 5.1620, val_acc: 0.0242
# Updated saved stanford cars model with validation accuracy = 0.0330
# Epoch [7], last_lr: 0.00020, train_loss: 5.0767, val_loss: 5.1052, val_acc: 0.0330
# Epoch [8], last_lr: 0.00024, train_loss: 5.0325, val_loss: 5.1137, val_acc: 0.0306
# Updated saved stanford cars model with validation accuracy = 0.0371
# Epoch [9], last_lr: 0.00028, train_loss: 4.9725, val_loss: 5.0740, val_acc: 0.0371
# Updated saved stanford cars model with validation accuracy = 0.0437
# Epoch [10], last_lr: 0.00032, train_loss: 4.8891, val_loss: 5.0122, val_acc: 0.0437
# Epoch [11], last_lr: 0.00037, train_loss: 4.7789, val_loss: 5.0574, val_acc: 0.0291
# Updated saved stanford cars model with validation accuracy = 0.0442
# Epoch [12], last_lr: 0.00042, train_loss: 4.6602, val_loss: 4.9184, val_acc: 0.0442
# Updated saved stanford cars model with validation accuracy = 0.0523
# Epoch [13], last_lr: 0.00047, train_loss: 4.5227, val_loss: 4.8549, val_acc: 0.0523
# Updated saved stanford cars model with validation accuracy = 0.0538
# Epoch [14], last_lr: 0.00052, train_loss: 4.3784, val_loss: 4.9396, val_acc: 0.0538
# Updated saved stanford cars model with validation accuracy = 0.0954
# Epoch [15], last_lr: 0.00057, train_loss: 4.2166, val_loss: 4.6751, val_acc: 0.0954
# Updated saved stanford cars model with validation accuracy = 0.1234
# Epoch [16], last_lr: 0.00062, train_loss: 4.0535, val_loss: 4.4714, val_acc: 0.1234
# Updated saved stanford cars model with validation accuracy = 0.1241
# Epoch [17], last_lr: 0.00067, train_loss: 3.8587, val_loss: 4.4550, val_acc: 0.1241
# Updated saved stanford cars model with validation accuracy = 0.1367
# Epoch [18], last_lr: 0.00072, train_loss: 3.6453, val_loss: 4.3310, val_acc: 0.1367
# Updated saved stanford cars model with validation accuracy = 0.2243
# Epoch [19], last_lr: 0.00076, train_loss: 3.4095, val_loss: 3.9875, val_acc: 0.2243
# Updated saved stanford cars model with validation accuracy = 0.2414
# Epoch [20], last_lr: 0.00080, train_loss: 3.2084, val_loss: 3.9765, val_acc: 0.2414
# Updated saved stanford cars model with validation accuracy = 0.2728
# Epoch [21], last_lr: 0.00084, train_loss: 3.0070, val_loss: 3.8756, val_acc: 0.2728
# Epoch [22], last_lr: 0.00088, train_loss: 2.8050, val_loss: 3.8481, val_acc: 0.2698
# Updated saved stanford cars model with validation accuracy = 0.3605
# Epoch [23], last_lr: 0.00091, train_loss: 2.6278, val_loss: 3.5068, val_acc: 0.3605
# Updated saved stanford cars model with validation accuracy = 0.3908
# Epoch [24], last_lr: 0.00094, train_loss: 2.4637, val_loss: 3.3917, val_acc: 0.3908
# Updated saved stanford cars model with validation accuracy = 0.4587
# Epoch [25], last_lr: 0.00096, train_loss: 2.3242, val_loss: 3.1920, val_acc: 0.4587
# Updated saved stanford cars model with validation accuracy = 0.4789
# Epoch [26], last_lr: 0.00098, train_loss: 2.2047, val_loss: 3.0399, val_acc: 0.4789
# Updated saved stanford cars model with validation accuracy = 0.5889
# Epoch [27], last_lr: 0.00099, train_loss: 2.1157, val_loss: 3.2011, val_acc: 0.5889
# Updated saved stanford cars model with validation accuracy = 0.5926
# Epoch [28], last_lr: 0.00100, train_loss: 1.9613, val_loss: 2.8604, val_acc: 0.5926
# Updated saved stanford cars model with validation accuracy = 0.6044
# Epoch [29], last_lr: 0.00100, train_loss: 1.8799, val_loss: 3.2738, val_acc: 0.6044
# Epoch [30], last_lr: 0.00100, train_loss: 1.7954, val_loss: 3.0486, val_acc: 0.5599
# Updated saved stanford cars model with validation accuracy = 0.6120
# Epoch [31], last_lr: 0.00100, train_loss: 1.7127, val_loss: 2.8421, val_acc: 0.6120
# Epoch [32], last_lr: 0.00100, train_loss: 1.6505, val_loss: 3.0359, val_acc: 0.5392
# Updated saved stanford cars model with validation accuracy = 0.7633
# Epoch [33], last_lr: 0.00099, train_loss: 1.5734, val_loss: 2.6118, val_acc: 0.7633
# Epoch [34], last_lr: 0.00099, train_loss: 1.5252, val_loss: 2.6770, val_acc: 0.7619
# Epoch [35], last_lr: 0.00098, train_loss: 1.4694, val_loss: 2.8301, val_acc: 0.7305
# Updated saved stanford cars model with validation accuracy = 0.7822
# Epoch [36], last_lr: 0.00098, train_loss: 1.4209, val_loss: 2.6504, val_acc: 0.7822
# Epoch [37], last_lr: 0.00097, train_loss: 1.3875, val_loss: 2.5527, val_acc: 0.7070
# Epoch [38], last_lr: 0.00096, train_loss: 1.3491, val_loss: 2.1657, val_acc: 0.7469
# Updated saved stanford cars model with validation accuracy = 0.7959
# Epoch [39], last_lr: 0.00095, train_loss: 1.3307, val_loss: 2.5763, val_acc: 0.7959
# Updated saved stanford cars model with validation accuracy = 0.8220
# Epoch [40], last_lr: 0.00094, train_loss: 1.2868, val_loss: 2.4749, val_acc: 0.8220
# Updated saved stanford cars model with validation accuracy = 0.8249
# Epoch [41], last_lr: 0.00093, train_loss: 1.2815, val_loss: 2.2392, val_acc: 0.8249
# Epoch [42], last_lr: 0.00092, train_loss: 1.2543, val_loss: 2.5513, val_acc: 0.8027
# Updated saved stanford cars model with validation accuracy = 0.8652
# Epoch [43], last_lr: 0.00090, train_loss: 1.2265, val_loss: 2.1333, val_acc: 0.8652
# Epoch [44], last_lr: 0.00089, train_loss: 1.1958, val_loss: 2.3223, val_acc: 0.8347
# Epoch [45], last_lr: 0.00088, train_loss: 1.1983, val_loss: 2.4907, val_acc: 0.8566
# Epoch [46], last_lr: 0.00086, train_loss: 1.1802, val_loss: 2.3376, val_acc: 0.7916
# Epoch [47], last_lr: 0.00085, train_loss: 1.1522, val_loss: 2.2009, val_acc: 0.8551
# Updated saved stanford cars model with validation accuracy = 0.8910
# Epoch [48], last_lr: 0.00083, train_loss: 1.1411, val_loss: 2.0391, val_acc: 0.8910
# Epoch [49], last_lr: 0.00081, train_loss: 1.1287, val_loss: 2.2189, val_acc: 0.8242
# Epoch [50], last_lr: 0.00079, train_loss: 1.1220, val_loss: 2.4688, val_acc: 0.8632
# Updated saved stanford cars model with validation accuracy = 0.9256
# Epoch [51], last_lr: 0.00078, train_loss: 1.1146, val_loss: 2.1011, val_acc: 0.9256
# Epoch [52], last_lr: 0.00076, train_loss: 1.0975, val_loss: 1.9871, val_acc: 0.8721
# Epoch [53], last_lr: 0.00074, train_loss: 1.0866, val_loss: 2.2543, val_acc: 0.9209
# Epoch [54], last_lr: 0.00072, train_loss: 1.0814, val_loss: 2.2482, val_acc: 0.9137
# Epoch [55], last_lr: 0.00070, train_loss: 1.0662, val_loss: 2.2897, val_acc: 0.9197
# Updated saved stanford cars model with validation accuracy = 0.9397
# Epoch [56], last_lr: 0.00068, train_loss: 1.0561, val_loss: 2.0712, val_acc: 0.9397
# Epoch [57], last_lr: 0.00065, train_loss: 1.0570, val_loss: 2.5815, val_acc: 0.8867
# Epoch [58], last_lr: 0.00063, train_loss: 1.0336, val_loss: 2.2247, val_acc: 0.9352
# Epoch [59], last_lr: 0.00061, train_loss: 1.0363, val_loss: 2.2952, val_acc: 0.9074
# Epoch [60], last_lr: 0.00059, train_loss: 1.0283, val_loss: 2.1093, val_acc: 0.8643
# Epoch [61], last_lr: 0.00057, train_loss: 1.0187, val_loss: 2.3255, val_acc: 0.8993
# Updated saved stanford cars model with validation accuracy = 0.9431
# Epoch [62], last_lr: 0.00054, train_loss: 1.0124, val_loss: 1.9864, val_acc: 0.9431
# Epoch [63], last_lr: 0.00052, train_loss: 1.0089, val_loss: 2.1798, val_acc: 0.9018
# Epoch [64], last_lr: 0.00050, train_loss: 1.0003, val_loss: 2.1400, val_acc: 0.8935
# Updated saved stanford cars model with validation accuracy = 0.9466
# Epoch [65], last_lr: 0.00048, train_loss: 0.9957, val_loss: 2.1060, val_acc: 0.9466
# Updated saved stanford cars model with validation accuracy = 0.9574
# Epoch [66], last_lr: 0.00046, train_loss: 0.9883, val_loss: 1.9202, val_acc: 0.9574
# Epoch [67], last_lr: 0.00043, train_loss: 0.9797, val_loss: 2.0808, val_acc: 0.9328
# Epoch [68], last_lr: 0.00041, train_loss: 0.9801, val_loss: 2.3029, val_acc: 0.9095
# Epoch [69], last_lr: 0.00039, train_loss: 0.9740, val_loss: 2.0930, val_acc: 0.9441
# Epoch [70], last_lr: 0.00037, train_loss: 0.9658, val_loss: 2.3274, val_acc: 0.9452
# Epoch [71], last_lr: 0.00035, train_loss: 0.9618, val_loss: 2.2406, val_acc: 0.9245
# Updated saved stanford cars model with validation accuracy = 0.9639
# Epoch [72], last_lr: 0.00032, train_loss: 0.9537, val_loss: 1.9855, val_acc: 0.9639
# Epoch [73], last_lr: 0.00030, train_loss: 0.9515, val_loss: 2.2215, val_acc: 0.9544
# Epoch [74], last_lr: 0.00028, train_loss: 0.9447, val_loss: 2.0525, val_acc: 0.9587
# Epoch [75], last_lr: 0.00026, train_loss: 0.9418, val_loss: 2.0721, val_acc: 0.9444
# Epoch [76], last_lr: 0.00024, train_loss: 0.9376, val_loss: 1.9803, val_acc: 0.9544
# Updated saved stanford cars model with validation accuracy = 0.9705
# Epoch [77], last_lr: 0.00022, train_loss: 0.9339, val_loss: 2.0124, val_acc: 0.9705
# Updated saved stanford cars model with validation accuracy = 0.9734
# Epoch [78], last_lr: 0.00021, train_loss: 0.9300, val_loss: 2.0507, val_acc: 0.9734
# Epoch [79], last_lr: 0.00019, train_loss: 0.9262, val_loss: 2.0179, val_acc: 0.9641
# Updated saved stanford cars model with validation accuracy = 0.9802
# Epoch [80], last_lr: 0.00017, train_loss: 0.9205, val_loss: 1.8942, val_acc: 0.9802
# Epoch [81], last_lr: 0.00015, train_loss: 0.9186, val_loss: 1.8375, val_acc: 0.9734
# Epoch [82], last_lr: 0.00014, train_loss: 0.9162, val_loss: 1.8942, val_acc: 0.9735
# Epoch [83], last_lr: 0.00012, train_loss: 0.9123, val_loss: 1.9113, val_acc: 0.9590
# Epoch [84], last_lr: 0.00011, train_loss: 0.9098, val_loss: 2.1787, val_acc: 0.9618
# Updated saved stanford cars model with validation accuracy = 0.9835
# Epoch [85], last_lr: 0.00010, train_loss: 0.9072, val_loss: 1.9353, val_acc: 0.9835
# Epoch [86], last_lr: 0.00008, train_loss: 0.9046, val_loss: 1.9742, val_acc: 0.9727
# Epoch [87], last_lr: 0.00007, train_loss: 0.9025, val_loss: 1.9638, val_acc: 0.9544
# Epoch [88], last_lr: 0.00006, train_loss: 0.9014, val_loss: 1.9462, val_acc: 0.9716
# Epoch [89], last_lr: 0.00005, train_loss: 0.8994, val_loss: 1.9580, val_acc: 0.9818
# Epoch [90], last_lr: 0.00004, train_loss: 0.8974, val_loss: 2.0244, val_acc: 0.9813
# Epoch [91], last_lr: 0.00003, train_loss: 0.8964, val_loss: 2.0471, val_acc: 0.9732
# Updated saved stanford cars model with validation accuracy = 0.9875
# Epoch [92], last_lr: 0.00002, train_loss: 0.8955, val_loss: 1.9960, val_acc: 0.9875
# Epoch [93], last_lr: 0.00002, train_loss: 0.8944, val_loss: 2.0258, val_acc: 0.9719
# Epoch [94], last_lr: 0.00001, train_loss: 0.8931, val_loss: 2.0442, val_acc: 0.9767
# Epoch [95], last_lr: 0.00001, train_loss: 0.8927, val_loss: 1.9192, val_acc: 0.9726
# Epoch [96], last_lr: 0.00000, train_loss: 0.8923, val_loss: 1.9391, val_acc: 0.9801
# Epoch [97], last_lr: 0.00000, train_loss: 0.8921, val_loss: 1.9694, val_acc: 0.9775
# Epoch [98], last_lr: 0.00000, train_loss: 0.8917, val_loss: 2.2115, val_acc: 0.9821
# Epoch [99], last_lr: 0.00000, train_loss: 0.8919, val_loss: 2.1593, val_acc: 0.9800
# CPU times: user 3h 57min 57s, sys: 3h 15min 46s, total: 7h 13min 43s
# Wall time: 7h 7min 35s

# %% [markdown]
# # Plotting

# %%
def plot_acc(history):
    plt.plot([x["val_acc"] for x in history],"-x")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")

def plot_loss(history):
    plt.plot([x.get("train_loss") for x in history], "-bx")
    plt.plot([x["val_loss"] for x in history],"-rx")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(["train loss","val loss"])
    
def plot_lrs(history):
    plt.plot(np.concatenate([x.get("lrs",[]) for x in history]))
    plt.xlabel("Batch number")
    plt.ylabel("Learning rate")

# %%
plot_loss(history)

# %%
plot_acc(history)

# %%
plot_lrs(history)

# %% [markdown]
# # Make predictions and see the image with its result

# %%
def predict_image(img, model):
    xb = to_device(img.unsqueeze(0), device)
    yb = model(xb)
    _, preds  = torch.max(yb, dim=1)
    return test_data.classes[preds[0].item()]

# %%
img, label = test_data[0]
plt.imshow(img.permute(1, 2, 0))
print('Label:', test_data.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4250312..1.8730049].
# Label: Audi TTS Coupe 2012 , Predicted: Audi TTS Coupe 2012

# %%
img, label = test_data[1002]
plt.imshow(img.permute(1, 2, 0))
print('Label:', test_data.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5742433..1.8457906].
# Label: Volkswagen Beetle Hatchback 2012 , Predicted: Volkswagen Beetle Hatchback 2012

# %% [markdown]
# ## Save

# %%
# torch.save(model.state_dict(), 'stanford_cars_resnet.pth')
